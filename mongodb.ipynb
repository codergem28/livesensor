# %%
pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in .\.venv\Lib\site-packages (4.2.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in .\.venv\Lib\site-packages (from pymongo[srv]) (2.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo
from pymongo import MongoClient

# %%
connection_string = "mongodb+srv://sudhanshumtripathi28_db_user:Sudhanshu28@cluster0.7erlj1d.mongodb.net/?appName=Cluster0"

# %%
client = MongoClient(connection_string)

# %%
db = client["Liveclass"]

# %%
collection = db["mongoclass"]

# %%
data = {
    "name":"Sudhanshu",
    "age":22,
    "email":"sudhanshumtripathi28@gmail.com"
}

# %%
collection.insert_one(data)

# %%
#fetching the data
cursor = collection.find{}
